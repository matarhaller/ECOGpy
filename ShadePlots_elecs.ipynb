# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from __future__ import division
import pandas as pd
import os
import loadmat
import scipy.stats as stats
import fdr_correct
import glob
import cPickle as pickle
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## calculate significane window for each elec within all clusters (both active an inactive)

# %%
SJdir = '/home/knight/matar/MATLAB/DATA/Avgusta/'
groupidx = os.path.join(SJdir, 'PCA','hclust', 'groupidx_hclust.csv')
df = pd.read_csv(groupidx)

# %%
reconlist = os.path.join(SJdir, 'PCA', 'reconlist.csv')
#reconlist = pd.ExcelFile(reconlist).parse('Sheet1')
reconlist = pd.read_csv(reconlist)

# %%
thresh = 10
chunk_size = 100
baseline = -500
black_chunk_size = 200

# %%
start_resp = -500
end_resp = 500

# %% [markdown]
# ## implemented in SGE as ShadePlots_allelecs_resp.py
# without plotting
# ### plot all resplocked - even if don't pass 10% threshold (for duration windows later)

# %%
from __future__ import division
import pandas as pd
import os
import loadmat
import scipy.stats as stats
import fdr_correct
import matplotlib.pyplot as plt
import numpy as np

# %%
# code that went into ShadePlots_allelecs_resp function
start_resp = -500
end_resp = 500
chunk_size = 100
#black_chunk_size = 200
#thresh = 10
black_chunk_size = 0
thresh = 0

for x in reconlist.values[[0]]:
    subj_task, _, _, _, _ = x
    subj, task = subj_task.split('_')

    filename = os.path.join(SJdir, 'Subjs', subj, task, 'HG_elecMTX_percent.mat')
    data = loadmat.loadmat(filename)
    srate = data['srate']
    active_elecs = data['active_elecs']
    RTs = data['RTs']
    params = data['Params']
    data = data['data_percent']

    #convert to srate
    bl_st = int(params['bl_st']/1000*srate)
    st_resp = int(start_resp/1000*srate)
    en_resp = int(end_resp/1000*srate)
    chunksize = chunk_size/1000*srate
    black_chunksize = black_chunk_size/1000*srate
    
    #shift RTs by baseline
    RTs = RTs + abs(bl_st)

    filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs','resplocked_all', ''.join([subj, '_', task, '_bigwindow.csv']))
    subjs = list(); tasks = list(); pthr = list(); elecs = list(); starts = list(); ends = list(); 

    for i, e in enumerate(active_elecs):
        if e!=3:
            continue

        pvals = list();
        edata = data[i,:]

        #create resplocked data
        edata_resp = np.zeros((len(RTs), len(np.arange(st_resp, en_resp))))
        RTs = RTs[RTs+st_resp>=0] #drop RTs that are too short
        #RTs = RTs[RTs+en_resp<=edata.shape[1]] #drop RTs that are too long (leaves only 3 at end - bad)

        for j, r in enumerate(RTs):
            edata_resp[j,:] = edata[j, r+st_resp:r+en_resp]
            #tmpdata = edata[j, r+st_resp:r+en_resp]
            #pad temp data with nan
            #edata_resp[j,:] = np.pad(tmpdata, ((0, edata_resp.shape[1]-len(tmpdata))), 'constant', constant_values=0)

        nozero = np.copy(edata_resp)
        nozero[:,nozero.mean(axis=0)<0] = 0 #zero out negative values

        for t in np.arange(0, edata_resp.shape[1]):
            (t, p) = stats.ttest_1samp(nozero[:,t], 0)
            pvals.append(p)

        thr = fdr_correct.fdr2(pvals, q = 0.05)
        H = np.array((pvals<thr)).astype('int')

        if (thr>0):

            #find elecs with window that > chunksize and > threshold (10%)
            passed_thresh = edata_resp.mean(axis=0)>thresh
            sig_and_thresh = H * passed_thresh
            difference = np.diff(sig_and_thresh, n = 1, axis = 0)
            start_idx = np.where(difference==1)[0]+1
            end_idx = np.where(difference == -1)[0]
            
            start_idx = start_idx+st_resp #shift by 500
            end_idx = end_idx+st_resp

            if start_idx.size > end_idx.size: #last chunk goes until end
                end_idx = np.append(end_idx, en_resp)

            elif start_idx.size < end_idx.size:
                start_idx = np.append(st_resp, start_idx) #starts immediately significant

            if (start_idx.size!=0):
                if (start_idx[0] > end_idx[0]): #starts immediately significant
                    start_idx = np.append(st_resp, start_idx)
            if (start_idx.size!=0):
                if (end_idx[-1] < start_idx[-1]):#significant until end
                    end_idx = np.append(end_idx, en_resp)

            chunk = (end_idx - start_idx) >= chunksize

            if sum(chunk) > 0:
                #significant windows on those that passed threshold (10%) (ignoring threshold and chunksize)
                difference = np.diff(H, n = 1, axis = 0)
                start_idx = np.where(difference==1)[0]+1
                end_idx = np.where(difference == -1)[0]
           
                start_idx = start_idx+st_resp #shift by 500
                end_idx = end_idx+st_resp

                if start_idx.size > end_idx.size: #last chunk goes until end
                    end_idx = np.append(end_idx, en_resp)

                elif start_idx.size < end_idx.size:
                    start_idx = np.append(st_resp, start_idx) #starts immediately significant

                if (start_idx.size!=0):
                    if (start_idx[0] > end_idx[0]): #starts immediately significant
                        start_idx = np.append(st_resp, start_idx)
                if (start_idx.size!=0):
                    if (end_idx[-1] < start_idx[-1]):#significant until end
                        end_idx = np.append(end_idx, en_resp)

                black_chunk = (start_idx[1:] - end_idx[:-1])> black_chunksize #combine window separated by <200ms

                tmp = np.append(1,black_chunk).astype('bool')
                end_idx = end_idx[np.append(np.where(np.in1d(start_idx, start_idx[tmp]))[0][1:]-1, -1)]
                start_idx = start_idx[tmp]           

                #drop chunks that <100ms
                chunk = (end_idx - start_idx) >= chunksize
                start_idx = start_idx[chunk]
                end_idx = end_idx[chunk]
            else: #no chunks
                start_idx = np.zeros((1,))
                end_idx = np.zeros((1,))
                
        else: #thr<0
            start_idx = np.zeros((1,))
            end_idx = np.zeros((1,))

        start_idx = np.round(start_idx/srate*1000) #convert to ms
        end_idx = np.round(end_idx/srate*1000)

        subjs.extend([subj] * len(start_idx))
        tasks.extend([task] * len(end_idx))
        elecs.extend([e] * len(start_idx))
        pthr.extend([thr] * len(end_idx))
        starts.extend(start_idx)
        ends.extend(end_idx)

# %%
#plot
f, ax = plt.subplots(figsize = (10,10))
scale_min = edata_resp.mean(axis = 0).min() - 10
if scale_min > 0:
    scale_min = -10
scale_max = edata_resp.mean(axis = 0).max() + 10
tmp = (np.arange(scale_min, scale_max))

ax.plot(np.arange(st_resp, en_resp), edata_resp.mean(axis = 0), zorder = 1, linewidth = 3)
sem = np.std(edata_resp, axis = 0)/np.sqrt(edata_resp.shape[0])
ax.fill_between(np.arange(st_resp, en_resp), edata_resp.mean(axis = 0)+sem, edata_resp.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
ax.plot(np.arange(st_resp, en_resp), np.zeros(edata_resp.shape[1]), color = 'k', linewidth = 3) #xaxis
ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
ax.set_ylabel('% change HG')
ax.set_xlabel('time (ms)')
ax.autoscale(tight=True)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

if start_idx.size>0:
    for i, s in enumerate(start_idx):
        tmp = np.arange(s, end_idx[i])
        start = s
        finish = end_idx[i]
        ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (start, finish))
        ax.legend()

ax.set_title(' '.join([subj, task, ':', elecname]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-c9ae6d8cb864> in <module>()
#      28         ax.legend()
#      29
# ---> 30 ax.set_title(' '.join([subj, task, ':', elecname]))
#
# NameError: name 'elecname' is not defined

# %% [markdown]
# ###plotting script (for resp)

# %%
reconlist.values[[47]]
# Out:
# array([['CP9_DecisionAud', 'CP9_recon.png', nan, 1000.0, 'r hemisphere']], dtype=object)

# %%
for x in reconlist.values[[43, 44, 45, 46, 47, 48]]:
    subj_task, _, _,_, _m = x
    subj, task = subj_task.split('_')
    
    files = glob.glob(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'resplocked_all', 'data', ''.join([subj, '_', task, '*.p'])))
    
    for f in files:
        elecname = f.split('_')[-1].split('.')[0]
        
        with open(f, 'r') as x:
            data_dict = pickle.load(x)
            x.close()
    
        #map dictionary to variables
        edata_resp, st_resp, en_resp, srate, start_idx, end_idx = [data_dict.get(k) for k in ['edata_resp','st_resp', 'en_resp', 'srate', 'start_idx', 'end_idx']]
        
        #plot
        f, ax = plt.subplots(figsize = (10,10))
        scale_min = edata_resp.mean(axis = 0).min() - 10
        if scale_min > 0:
            scale_min = -10
        scale_max = edata_resp.mean(axis = 0).max() + 10
        tmp = (np.arange(scale_min, scale_max))

        ax.plot(np.arange(st_resp, en_resp), edata_resp.mean(axis = 0), zorder = 1, linewidth = 3)
        sem = np.std(edata_resp, axis = 0)/np.sqrt(edata_resp.shape[0])
        ax.fill_between(np.arange(st_resp, en_resp), edata_resp.mean(axis = 0)+sem, edata_resp.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
        ax.plot(np.arange(st_resp, en_resp), np.zeros(edata_resp.shape[1]), color = 'k', linewidth = 3) #xaxis
        ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
        ax.set_ylabel('% change HG')
        ax.set_xlabel('time (ms)')
        ax.autoscale(tight=True)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()

        if start_idx.size>0:
            for i, s in enumerate(start_idx):
                tmp = np.arange(s, end_idx[i])
                start = s
                finish = end_idx[i]
                ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (start, finish))
                ax.legend()

        ax.set_title(' '.join([subj, task, ':', elecname]))
        plt.savefig(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs','resplocked_all', 'images', ''.join([subj, '_', task, '_', elecname, '_resplocked'])))
        plt.close()

# %% [markdown]
# ## plot output from SGE for ShadePlots_allelecs.py
# #### if gap is <= 200ms then combine chunks
# #### then throw out chunks that < 100ms
#
# ###plotting script

# %%
reconlist.values[[43, 44, 45, 46, 47, 48]]
# Out:
# array([['ST27_DecisionVis', 'ST27_recon_grouped_labeled.png', nan, 1000.0,
#         'good, has medial activity'],
#        ['ST28_DecisionVis', 'ST28_recon.png', nan, 1000.0, nan],
#        ['GP44_DecisionAud', 'GP44_recon.png', nan, 1000.0, nan],
#        ['CP7_DecisionAud', 'CP7_recon.png', nan, 1000.0, nan],
#        ['CP9_DecisionAud', 'CP9_recon.png', nan, 1000.0, 'r hemisphere'],
#        ['ST32_DecisionVis', 'ST32_recon.png', nan, 1000.0, nan]], dtype=object)

# %%
for x in reconlist.values[[43, 44, 45, 46, 47, 48]]:
    subj_task, _, _,_, _ = x
    subj, task = subj_task.split('_')
    
    files = glob.glob(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'data', ''.join([subj, '_', task, '*.p'])))
    
    for f in files:
        elecname = f.split('_')[-1].split('.')[0]
        
        with open(f, 'r') as x:
            data_dict = pickle.load(x)
            x.close()
    
        #map dictionary to variables
        edata, bl_st, srate, start_idx, end_idx = [data_dict.get(k) for k in ['edata','bl_st', 'srate', 'start_idx', 'end_idx']]
        
        #plot
        f, ax = plt.subplots(figsize = (10,10))
        scale_min = edata.mean(axis = 0).min() - 10
        scale_max = edata.mean(axis = 0).max() + 10
        tmp = (np.arange(scale_min, scale_max))

        ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0), zorder = 1, linewidth = 3)
        sem = np.std(edata, axis = 0)/np.sqrt(edata.shape[0])
        ax.fill_between(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0)+sem, edata.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
        ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), np.zeros(edata.shape[1]), color = 'k', linewidth = 3) #xaxis
        ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
        ax.set_ylabel('% change HG')
        ax.set_xlabel('time (ms)')
        ax.autoscale(tight=True)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()

        if start_idx.size>0:
            for i, s in enumerate(start_idx):
                tmp = np.arange(s, end_idx[i])
                start = int(s/srate*1000)
                finish = int(end_idx[i]/srate*1000)
                ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (start, finish))
                ax.legend()

        ax.set_title(' '.join([subj, task, ':', elecname]))
        plt.savefig(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs','images', ''.join([subj, '_', task, '_', elecname, '_bigwindow'])))
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-83a5936ee983> in <module>()
#       9
#      10         with open(f, 'r') as x:
# ---> 11             data_dict = pickle.load(x)
#      12             x.close()
#      13
#
# KeyboardInterrupt:

# %% [markdown]
# ## implemented in ShadePlots_allelecs.py for SGE - without plotting
# ### if gap is <=200 ms then combine chunks
# ### not including a 100ms threshold cutoff

# %%
black_chunk_size = 200

# STIM LOCKED
for x in reconlist.values:
    subj_task, _, _, _, _ = x
    subj, task = subj_task.split('_')

    subj_task = df[(df.subj.isin([subj])) & (df.task.isin([task]))]
    subj_task = subj_task.sort('active_elec')
    weights = subj_task[['group', 'active_elec']] 

    filename = os.path.join(SJdir, 'Subjs', subj, task, 'HG_elecMTX_percent.mat')
    data = loadmat.loadmat(filename)
    srate = data['srate']
    data = data['data_percent']
    
    bl_st = baseline/1000*srate
    
    chunksize = chunk_size/1000*srate
    black_chunksize = black_chunk_size/1000*srate
    
    if task in ['DecisionAud']:
        st_tp = 600/1000*srate
    elif task in ['DecisionVis']:
        st_tp = 500/1000*srate
    else:
        st_tp = 0

    filename = os.path.join(SJdir, 'PCA', 'ShadePlots_elecs', ''.join([subj, '_', task, '_bigwindow.csv']))
    subjs = list(); tasks = list(); pthr = list(); groups = list(); elecs = list(); starts = list(); ends = list(); chunks = list()
    
    for i, e in enumerate(weights.active_elec):
        if e !=80:
            continue
        pvals = list(); tvals = list()
        edata = data[i,:]
        nozero = np.copy(edata)
        nozero[:,nozero.mean(axis=0)<0] = 0 #zero out negative values

        for t in np.arange(abs(bl_st)+st_tp, edata.shape[1]):
            #(t, p) = stats.ttest_1samp(edata[:,t], 0)
            (t, p) = stats.ttest_1samp(nozero[:,t], 0)
            pvals.append(p)
            tvals.append(t)

        thr = fdr_correct.fdr2(pvals, q = 0.05)
        H = np.array((pvals<thr)).astype('int')

        if (thr>0):
            
            #find elecs with window that > chunksize and > threshold (10%)
            passed_thresh = edata[:, abs(bl_st)+st_tp::].mean(axis=0)>thresh
            sig_and_thresh = H * passed_thresh
            difference = np.diff(sig_and_thresh, n = 1, axis = 0)
            start_idx = np.where(difference==1)[0]+1
            end_idx = np.where(difference == -1)[0]

            if start_idx.size > end_idx.size: #last chunk goes until end
                end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))

            elif start_idx.size < end_idx.size:
                start_idx = np.append(0, start_idx) #starts immediately significant

            if (start_idx.size!=0):
                if (start_idx[0] > end_idx[0]): #starts immediately significant
                    start_idx = np.append(0, start_idx)
            if (start_idx.size!=0):
                if (end_idx[-1] < start_idx[-1]):#significant until end
                    end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))


            start_idx = start_idx + st_tp #shift by st_tp
            end_idx = end_idx + st_tp
            chunk = (end_idx - start_idx) >= chunksize
            if sum(chunk) == 0:
                continue
            
            #significant windows on those that passed threshold (10%) (ignoring threshold and chunksize)
            difference = np.diff(H, n = 1, axis = 0)
            start_idx = np.where(difference==1)[0]+1
            end_idx = np.where(difference == -1)[0]

            if start_idx.size > end_idx.size: #last chunk goes until end
                end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))

            elif start_idx.size < end_idx.size:
                start_idx = np.append(0, start_idx) #starts immediately significant

            if (start_idx.size!=0):
                if (start_idx[0] > end_idx[0]): #starts immediately significant
                    start_idx = np.append(0, start_idx)
            if (start_idx.size!=0):
                if (end_idx[-1] < start_idx[-1]):#significant until end
                    end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))

            start_idx = start_idx + st_tp #shift by st_tp
            end_idx = end_idx + st_tp

            black_chunk = (start_idx[1:] - end_idx[:-1])> black_chunksize #combine window separated by <200ms

            tmp = np.append(1,black_chunk).astype('bool')
            end_idx = end_idx[np.append(np.where(np.in1d(start_idx, start_idx[tmp]))[0][1:]-1, -1)]
            start_idx = start_idx[tmp]           
            
            #drop chunks that <100ms
            chunk = (end_idx - start_idx) >= chunksize
            start_idx = start_idx[chunk]
            end_idx = end_idx[chunk]
            
        else:
            start_idx = np.array(())
            end_idx = np.array(())
            chunk = np.array(())

        subjs.extend([subj] * len(start_idx))
        tasks.extend([task] * len(end_idx))
        groups.extend([int(weights.group[weights.active_elec==e])] * len(start_idx))
        elecs.extend([e] * len(start_idx))
        pthr.extend([thr] * len(end_idx))
        starts.extend(start_idx)
        ends.extend(end_idx)
        chunks.extend(chunk)

        #plot
        f, ax = plt.subplots(figsize = (10,10))
        scale_min = edata.mean(axis = 0).min() - 10
        scale_max = edata.mean(axis = 0).max() + 10
        tmp = (np.arange(scale_min, scale_max))

        ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0), zorder = 1, linewidth = 3)
        sem = np.std(edata, axis = 0)/np.sqrt(edata.shape[0])
        ax.fill_between(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0)+sem, edata.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
        ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), np.zeros(edata.shape[1]), color = 'k', linewidth = 3) #xaxis
        ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
        ax.set_ylabel('% change HG')
        ax.set_xlabel('time (ms)')
        ax.autoscale(tight=True)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()

        if start_idx.size>0:
            for i, s in enumerate(start_idx):
                tmp = np.arange(s, end_idx[i])
                start = int(s/srate*1000)
                finish = int(end_idx[i]/srate*1000)
                ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (start, finish))
                ax.legend()

        ax.set_title(' '.join([subj, task, ':', 'electrode', str(e), '-', 'cluster', str(int(weights.group[weights.active_elec==e]))]))
        savefig(os.path.join(SJdir, 'PCA', 'ShadePlots_elecs', ''.join([subj, '_', task,'_c',str(int(weights.group[weights.active_elec==e])), '_e', str(e), '_bigwindow'])))
        plt.close()

    #sig_windows = pd.DataFrame({'subj':subjs, 'task':tasks, 'group':groups, 'elec':elecs, 'pthreshold':pthr, 'start_idx':starts, 'end_idx':ends, 'chunk':chunks})
    #sig_windows = sig_windows[['subj','task', 'group','elec', 'start_idx','end_idx','pthreshold', 'chunk']]
    sig_windows = pd.DataFrame({'subj':subjs, 'task':tasks, 'group':groups, 'elec':elecs, 'pthreshold':pthr, 'start_idx':starts, 'end_idx':ends})
    sig_windows = sig_windows[['subj','task', 'group','elec', 'start_idx','end_idx','pthreshold']]
    
    sig_windows.to_csv(filename)

# %% [markdown]
# ## combine all the shadeplots_elecs csv for each subject

# %%
import os
import pandas as pd

# %%
SJdir = '/home/knight/matar/MATLAB/DATA/Avgusta/'

reconlist = os.path.join(SJdir, 'PCA', 'reconlist.csv')
reconlist = pd.read_csv(reconlist)

# %%
dfall_stim = pd.DataFrame()
dfall_resp = pd.DataFrame()

for i,x in enumerate(reconlist.values):
    
    subj_task, recon,_,_,_ = x
    subj, task = subj_task.split('_')
    
    if isinstance(recon, float): #recon doesn't exist
        continue
        
    filename = os.path.join(SJdir, 'PCA','ShadePlots_allelecs',  ''.join([subj, '_', task, '_bigwindow.csv'])) #STIM
    df = pd.DataFrame.from_csv(filename,index_col = 0)

    dfall_stim = dfall_stim.append(df)
    
    filename = os.path.join(SJdir, 'PCA','ShadePlots_allelecs', 'resplocked_all', ''.join([subj, '_', task, '.csv'])) #RESP
    df = pd.DataFrame.from_csv(filename,index_col = 0)

    dfall_resp = dfall_resp.append(df)

# %%
filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'shadeplots_stim_bigwindow.csv')
dfall_stim.to_csv(filename)

filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'resplocked_all', 'shadeplots_resp.csv')
dfall_resp.to_csv(filename)

# %% [markdown]
# ## add T/F to csv if elec is part of duration cluster

# %%
df_dur = pd.read_csv(os.path.join(SJdir, 'PCA', 'duration_dict_500', 'groupidx_activeclusters_hclust_withduration_thresh15_maxRTlocked_withcriteria.csv'))

# %%
#STIM
print ''
df_shade = pd.read_csv(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'shadeplots_stim_bigwindow.csv'))
df_shade = df_shade[['subj','task','elec', 'start_idx','end_idx','pthreshold']]

df_dur = pd.read_csv(os.path.join(SJdir, 'PCA', 'duration_dict_500', 'groupidx_activeclusters_hclust_withduration_thresh15_maxRTlocked_withcriteria.csv'))
df_dur = df_dur[['subj','task','group','active_elecs', 'all_criteria_passed', 'best_offset_less-300','max_resplocked_more-50']]
df_dur.columns = ['subj','task','group','elec','all_criteria_passed', 'best_offset_less-300','max_resplocked_more-50']

df_all = pd.merge(df_shade, df_dur, how = 'outer', on = ['subj','task','elec']) 

df_all = df_all[['subj','task', 'group','elec','start_idx','end_idx','pthreshold', 'all_criteria_passed','best_offset_less-300','max_resplocked_more-50' ]]


#dropped subj/blocks:
print np.setdiff1d(pd.merge(df_shade, df_dur, how = 'outer').subj, pd.merge(df_shade, df_dur, how = 'inner').subj)
#print np.intersect1d(df_dur.loc[(df_dur.subj=='JH10') & (df_dur.task == 'EmoRep')].elec.values, unique(df_shade.loc[(df_shade.subj=='JH10') & (df_shade.task == 'EmoRep')].elec.values))

df_all.to_csv(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'shadeplots_stim_bigwindow_withduration.csv'))
# Out:
# []

# %%
#RESP
print ''
df_shade = pd.read_csv(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'resplocked_all', 'shadeplots_resp.csv'))
df_shade = df_shade[['subj','task','elec', 'start_idx','end_idx','pthreshold']]

df_dur = pd.read_csv(os.path.join(SJdir, 'PCA', 'duration_dict_500', 'groupidx_activeclusters_hclust_withduration_thresh15_maxRTlocked_withcriteria.csv'))
df_dur = df_dur[['subj','task','group','active_elecs', 'all_criteria_passed', 'best_offset_less-300','max_resplocked_more-50']]
df_dur.columns = ['subj','task','group','elec','all_criteria_passed', 'best_offset_less-300','max_resplocked_more-50']

df_all = pd.merge(df_shade, df_dur, how = 'outer', on = ['subj','task','elec']) 

df_all = df_all[['subj','task', 'group','elec','start_idx','end_idx','pthreshold', 'all_criteria_passed','best_offset_less-300','max_resplocked_more-50' ]]


#dropped subj/blocks:
print np.setdiff1d(pd.merge(df_shade, df_dur, how = 'outer').subj, pd.merge(df_shade, df_dur, how = 'inner').subj)
#print np.intersect1d(df_dur.loc[(df_dur.subj=='JH10') & (df_dur.task == 'EmoRep')].elec.values, unique(df_shade.loc[(df_shade.subj=='JH10') & (df_shade.task == 'EmoRep')].elec.values))

df_all.to_csv(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'resplocked_all','shadeplots_resp_withduration.csv'))
# Out:
# []

# %% [markdown]
# ## drop all but the first window for elecs with multiple windows

# %%
#STIM
filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'shadeplots_stim_bigwindow_withduration.csv')
dfall_stim = pd.read_csv(filename)

dfall_stim.columns
dfall_stim = dfall_stim.drop_duplicates(cols = ['subj','task','group','elec'])

filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'shadeplots_stim_bigwindow_wthduration_drop_duplicates.csv')
dfall_stim.to_csv(filename)
# Out:
# /usr/local/anaconda/lib/python2.7/site-packages/pandas-0.14.0-py2.7-linux-x86_64.egg/pandas/util/decorators.py:53: FutureWarning: cols is deprecated, use subset instead
#   warnings.warn(msg, FutureWarning)

# %%
#RESP
filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'resplocked_all', 'shadeplots_resp_withduration.csv')
dfall_resp = pd.read_csv(filename)

dfall_resp.columns
dfall_resp = dfall_resp.drop_duplicates(cols = ['subj','task','elec'])

filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'resplocked_all', 'shadeplots_resp_drop_duplicates.csv')
dfall_resp.to_csv(filename)

# %%
#combine STIM and RESP bigwindow with duration csvs
filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'resplocked_all', 'shadeplots_resp_drop_duplicates.csv')
df_resp = pd.read_csv(filename)

df_resp = df_resp[['subj','task', 'group', 'elec', 'start_idx', 'end_idx', 'pthreshold', 'all_criteria_passed', 'best_offset_less-300', 'max_resplocked_more-50']]
df_resp.columns = ['subj','task', 'group', 'elec', 'start_idx_resp', 'end_idx_resp', 'pthreshold', 'all_criteria_passed', 'best_offset_less-300', 'max_resplocked_more-50']

filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'shadeplots_stim_bigwindow_wthduration_drop_duplicates.csv')
df_stim = pd.read_csv(filename)
df_stim = df_stim[['subj','task', 'group', 'elec', 'start_idx', 'end_idx', 'pthreshold', 'all_criteria_passed', 'best_offset_less-300', 'max_resplocked_more-50']]

# %%
df_all = df_stim.merge(df_resp, on = ['subj','task', 'group', 'elec', 'all_criteria_passed', 'best_offset_less-300', 'max_resplocked_more-50'], how = 'outer')

df_all = df_all[['subj','task', 'group', 'elec', 'start_idx', 'end_idx', 'start_idx_resp', 'end_idx_resp', 'all_criteria_passed', 'best_offset_less-300', 'max_resplocked_more-50']]


filename = os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', 'shadeplots_stim_resp_bigwindow_withduration_drop_duplicates.csv')
df_all.to_csv(filename)

print ' '
print df_all.shape
print df_resp.shape
print df_stim.shape
# Out:
#
# (1051, 11)
# (1051, 10)
# (1051, 10)

# %% [markdown]
# # *** OLD ***
# ### calculate significance window for each elec within duration cluster - OLD
# #### plot and write to csv

# %%
SJdir = '/home/knight/matar/MATLAB/DATA/Avgusta/'
groupidx = os.path.join(SJdir, 'PCA','duration_dict', 'groupidx_activeclusters_hclust_withduration_thresh15_maxRTlocked.csv')
df = pd.read_csv(groupidx)

# %%
reconlist = os.path.join(SJdir, 'PCA', 'reconlist.xlsx')
reconlist = pd.ExcelFile(reconlist).parse('Sheet1')

# %%
chunksize = 100
baseline = -500

# %%
print reconlist.values[28]
# Out:
# [u'GP15_EmoGen' u'GP15_Lateral_Left_blankelecs.png' nan u'good']

# %%
for x in reconlist.values:
    subj_task, _, _, _ = x
    subj, task = subj_task.split('_')

    subj_task = df[(df.subj.isin([subj])) & (df.task.isin([task]))]
    subj_task = subj_task.sort('active_elecs')
    weights = subj_task[['group', 'active_elecs']] #.loc[(subj_task.best_offset>-300)]

    filename = os.path.join(SJdir, 'Subjs', subj, task, 'HG_elecMTX_percent.mat')
    data = loadmat.loadmat(filename)
    active_elecs = data['active_elecs']
    srate = data['srate']
    data = data['data_percent']

    bl_st = baseline/1000*srate

    if task in ['DecisionAud']:
        st_tp = 600/1000*srate
    elif task in ['DecisionVis']:
        st_tp = 500/1000*srate
    else:
        st_tp = 0

    filename = os.path.join(SJdir, 'PCA', 'ShadePlots_elecs', ''.join([subj, '_', task, '.csv']))
    subjs = list(); tasks = list(); pthr = list(); groups = list(); elecs = list(); starts = list(); ends = list()

    for g in weights.groupby('group'):
        cluster_elecs = g[1].active_elecs
        idx = np.in1d(active_elecs, cluster_elecs)
        cdata = data[idx,:,:]

        for i, e in enumerate(cluster_elecs):
           
            pvals = list(); tstat = list()
            edata = cdata[i,:]

            for t in np.arange(abs(bl_st)+st_tp, edata.shape[1]):
                (t, p) = stats.ttest_1samp(edata[:,t], 0)
                pvals.append(p)
                #tstat.append(t.flatten())

            thr = fdr_correct.fdr2(pvals, q = 0.05)
            #H = ((pvals<thr) & (tstat>0)).astype('int')
            H = np.array((pvals<thr)).astype('int')
            
            if (thr>0):
                #significant windows that > chunksize (ignoring threshold)
                difference = np.diff(H, n = 1, axis = 0)
                start_idx = np.where(difference==1)[0]+1
                end_idx = np.where(difference == -1)[0]

                if start_idx.size > end_idx.size: #last chunk goes until end
                    end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))

                elif start_idx.size < end_idx.size:
                    start_idx = np.append(0, start_idx) #starts immediately significant

                if (start_idx.size!=0):
                    if (start_idx[0] > end_idx[0]): #starts immediately significant
                        start_idx = np.append(0, start_idx)
                if (start_idx.size!=0):
                    if (end_idx[-1] < start_idx[-1]):#significant until end
                        end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))


                start_idx = start_idx + st_tp #shift by st_tp
                end_idx = end_idx + st_tp

                chunks = (end_idx - start_idx) >= chunksize

                start_idx = start_idx[chunks]
                end_idx = end_idx[chunks]
            else:
                start_idx = np.array(())
                end_idx = np.array(())

            subjs.extend([subj] * len(start_idx))
            tasks.extend([task] * len(end_idx))
            groups.extend([int(g[0])] * len(end_idx))
            elecs.extend([e] * len(end_idx))
            pthr.extend([thr] * len(end_idx))
            starts.extend(start_idx)
            ends.extend(end_idx)

            #plot
            f, ax = plt.subplots(figsize = (10,10))
            scale_min = edata.mean(axis = 0).min() - 10
            scale_max = edata.mean(axis = 0).max() + 10
            tmp = (np.arange(scale_min, scale_max))

            ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0), zorder = 1, linewidth = 3)
            sem = np.std(edata, axis = 0)/np.sqrt(edata.shape[0])
            ax.fill_between(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0)+sem, edata.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
            ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), np.zeros(edata.shape[1]), color = 'k', linewidth = 3) #xaxis
            ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
            ax.set_ylabel('% change HG')
            ax.set_xlabel('time (ms)')
            ax.autoscale(tight=True)
            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
            ax.get_xaxis().tick_bottom()
            ax.get_yaxis().tick_left()

            if start_idx.size>0:
                for i, s in enumerate(start_idx):
                    tmp = np.arange(s, end_idx[i])
                    start = int(s/srate*1000)
                    finish = int(end_idx[i]/srate*1000)
                    ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (start, finish))
                ax.legend()

            ax.set_title(' '.join([subj, task, ':', 'electrode', str(e), '-', 'cluster', str(int(g[0]))]))
            savefig(os.path.join(SJdir, 'PCA', 'ShadePlots_elecs', ''.join([subj, '_', task,'_c', str(int(g[0])),'_e', str(e)])))
            plt.close()

    sig_windows = pd.DataFrame({'subj':subjs, 'task':tasks, 'group':groups, 'elec':elecs, 'pthreshold':pthr, 'start_idx':starts, 'end_idx':ends})
    sig_windows = sig_windows[['subj','task', 'group','elec', 'start_idx','end_idx','pthreshold']]
    sig_windows.to_csv(filename)

# %%
## FOR 1 SUBJ/CLUSTER

for x in reconlist.values[[28]]:
    subj_task, _, _, _ = x
    subj, task = subj_task.split('_')

    subj_task = df[(df.subj.isin([subj])) & (df.task.isin([task]))]
    subj_task = subj_task.sort('active_elecs')
    weights = subj_task[['group', 'active_elecs']] #.loc[(subj_task.best_offset>-300)]

    filename = os.path.join(SJdir, 'Subjs', subj, task, 'HG_elecMTX_percent.mat')
    data = loadmat.loadmat(filename)
    active_elecs = data['active_elecs']
    srate = data['srate']
    data = data['data_percent']

    bl_st = baseline/1000*srate

    if task in ['DecisionAud']:
        st_tp = 600/1000*srate
    elif task in ['DecisionVis']:
        st_tp = 500/1000*srate
    else:
        st_tp = 0

    filename = os.path.join(SJdir, 'PCA', 'ShadePlots_elecs', ''.join([subj, '_', task, '.csv']))
    subjs = list(); tasks = list(); pthr = list(); groups = list(); elecs = list(); starts = list(); ends = list()

    for g in weights.groupby('group'):
       
        if int(g[0]) != 1:
            continue
        cluster_elecs = g[1].active_elecs
        idx = np.in1d(active_elecs, cluster_elecs)
        cdata = data[idx,:,:]

        for i, e in enumerate(cluster_elecs):
            if e != 2:
                continue
           
            pvals = list(); tstat = list()
            edata = cdata[i,:]

            for t in np.arange(abs(bl_st)+st_tp, edata.shape[1]):
                (t, p) = stats.ttest_1samp(edata[:,t], 0)
                pvals.append(p)
                #tstat.append(t.flatten())

            thr = fdr_correct.fdr2(pvals, q = 0.05)
            #H = ((pvals<thr) & (tstat>0)).astype('int')
            H = np.array((pvals<thr)).astype('int')
            
            if (thr>0):
                #significant windows that > chunksize (ignoring threshold)
                difference = np.diff(H, n = 1, axis = 0)
                start_idx = np.where(difference==1)[0]+1
                end_idx = np.where(difference == -1)[0]

                if start_idx.size > end_idx.size: #last chunk goes until end
                    end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))

                elif start_idx.size < end_idx.size:
                    start_idx = np.append(0, start_idx) #starts immediately significant

                if (start_idx.size!=0):
                    if (start_idx[0] > end_idx[0]): #starts immediately significant
                        start_idx = np.append(0, start_idx)
                if (start_idx.size!=0):
                    if (end_idx[-1] < start_idx[-1]):#significant until end
                        end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))


                start_idx = start_idx + st_tp #shift by st_tp
                end_idx = end_idx + st_tp

                chunks = (end_idx - start_idx) >= chunksize

                start_idx = start_idx[chunks]
                end_idx = end_idx[chunks]
            else:
                start_idx = np.array(())
                end_idx = np.array(())

            subjs.extend([subj] * len(start_idx))
            tasks.extend([task] * len(end_idx))
            groups.extend([int(g[0])] * len(end_idx))
            elecs.extend([e] * len(end_idx))
            pthr.extend([thr] * len(end_idx))
            starts.extend(start_idx)
            ends.extend(end_idx)

            #plot
            f, ax = plt.subplots(figsize = (10,10))
            scale_min = edata.mean(axis = 0).min() - 10
            scale_max = edata.mean(axis = 0).max() + 10
            tmp = (np.arange(scale_min, scale_max))

            ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0), zorder = 1, linewidth = 3)
            sem = np.std(edata, axis = 0)/np.sqrt(edata.shape[0])
            ax.fill_between(np.arange(bl_st, edata.shape[1]+bl_st), edata.mean(axis = 0)+sem, edata.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
            ax.plot(np.arange(bl_st, edata.shape[1]+bl_st), np.zeros(edata.shape[1]), color = 'k', linewidth = 3) #xaxis
            ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
            ax.set_ylabel('% change HG')
            ax.set_xlabel('time (ms)')
            ax.autoscale(tight=True)
            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
            ax.get_xaxis().tick_bottom()
            ax.get_yaxis().tick_left()

            if start_idx.size>0:
                for i, s in enumerate(start_idx):
                    tmp = np.arange(s, end_idx[i])
                    start = int(s/srate*1000)
                    finish = int(end_idx[i]/srate*1000)
                    ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (start, finish))
                ax.legend()

# %%
plot(pvals)
plot(np.arange(len(pvals)), np.tile(pthr, len(pvals)), 'r')
