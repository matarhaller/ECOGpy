# %%
# %pylab qt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import numpy as np
from utils.loadmat import loadmat
import mne

# %%
data_dict = loadmat('/home/knight/matar/MATLAB/DATA/Avgusta/Subjs/GP15/EmoGen/gdat_notch.mat')
gdat = data_dict['gdat']

# %%
gdat.shape
# Out:
# (84, 1476035)

# %%
info = mne.create_info(84, sfreq = 1017.3, ch_types = 'eeg')
raw = mne.io.RawArray(gdat, info)
# Out:
# Creating RawArray with float64 data, n_channels=84, n_times=1476035
#     Range : 0 ... 1476034 =      0.000 ...  1450.933 secs
# Ready.

# %%
raw.plot()
# Out:
# /usr/local/anaconda-2.4.0/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /usr/local/anaconda-2.4.0/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
