# %%
from __future__ import division
import pandas as pd
import os
import loadmat
import scipy.stats as stats
import fdr_correct
import glob
import cPickle as pickle
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
SJdir = '/home/knight/matar/MATLAB/DATA/Avgusta/'
reconlist = os.path.join(SJdir, 'PCA', 'reconlist.csv')
reconlist = pd.read_csv(reconlist)

# %% [markdown]
# ## combine output from shadeplots_clusters

# %%
df_stim = pd.DataFrame()
df_resp = pd.DataFrame()

for x in reconlist.values:
    s_t, reconfile, _, _, _ = x
    subj, task = s_t.split('_')
    
    if isinstance(reconfile, float):
        continue #no reconfile, blank - skip subj
    
    #pull out significant clusters - STIMULUS LOCKED
    filename = os.path.join(SJdir,'PCA', 'ShadePlots_hclust', ''.join([s_t, '.csv']))
    df_st = pd.read_csv(filename)
    
    df_stim = df_stim.append(df_st)
    
    #pull out significant clusters - RESPONSE LOCKED
    filename = os.path.join(SJdir,'PCA', 'ShadePlots_hclust', 'resplocked_all_thresh5', ''.join([s_t, '.csv']))
   
    df_st = pd.read_csv(filename)
    df_resp = df_resp.append(df_st)

# %%
filename = os.path.join(SJdir, 'PCA', 'ShadePlots_hclust', 'shadeplots_cluster_stim.csv')
df_stim.to_csv(filename)

# %%
df_stim  = df_stim.drop_duplicates(['subj','task', 'cluster'])

# %%
filename = os.path.join(SJdir, 'PCA', 'ShadePlots_hclust','resplocked_all_thresh5', 'shadeplots_cluster_resp.csv')
df_resp.to_csv(filename)

# %%
df_resp = df_resp.drop_duplicates(['subj','task', 'cluster'])
df_resp = df_resp[['subj','task','cluster','start_idx','end_idx']]
df_resp.columns = ['subj','task','cluster','start_idx_resp','end_idx_resp']

# %%
df_all = pd.merge(df_stim, df_resp, how = 'outer')

# %%
filename = os.path.join(SJdir, 'PCA', 'duration_dict_500', 'groupidx_activeclusters_hclust_withduration_thresh15_maxRTlocked_withcriteria_ROI.csv')
df_full = pd.read_csv(filename)

# %%
df_full = df_full[['subj','task','group','all_criteria_passed']]

# %%
df_full.columns = ['subj','task','cluster','all_criteria_passed']

# %%
df = pd.merge(df_all, df_full, on = ['subj','task','cluster'], how = 'outer')

# %%
df = df.drop_duplicates(['subj','task','cluster'])

# %%
filename = os.path.join(SJdir, 'PCA','ShadePlots_hclust', 'stim_resp_cluster_windows_withduration.csv')
df.to_csv(filename)

# %% [markdown]
# ##plotting script for output from ShadePlots_clusters.py

# %%
for x in reconlist.values:
    subj_task, _, _,_, _ = x
    subj, task = subj_task.split('_')
    
    files = glob.glob(os.path.join(SJdir, 'PCA', 'ShadePlots_hclust', 'data', ''.join([subj, '_', task, '*.p'])))
    
    for f in files:
        clustername = f.split('_')[-1].split('.')[0]
        
        with open(f, 'r') as x:
            data_dict = pickle.load(x)
            x.close()
    
        #map dictionary to variables
        cdata, bl_st, srate, start_idx, end_idx, chunksize, black_chunksize, cluster, thresh = [data_dict.get(k) for k in ['cdata','bl_st', 'srate', 'start_idx', 'end_idx', 'chunksize', 'black_chunksize', 'cluster', 'thresh']]
        
        #plot
        f, ax = plt.subplots(figsize = (10,10))
        scale_min = cdata.mean(axis = 0).min() - 10
        scale_max = cdata.mean(axis = 0).max() + 10
        tmp = (np.arange(scale_min, scale_max))

        ax.plot(np.arange(bl_st, cdata.shape[1]+bl_st), cdata.mean(axis = 0), zorder = 1, linewidth = 3)
        sem = np.std(cdata, axis = 0)/np.sqrt(cdata.shape[0])
        ax.fill_between(np.arange(bl_st, cdata.shape[1]+bl_st), cdata.mean(axis = 0)+sem, cdata.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
        ax.plot(np.arange(bl_st, cdata.shape[1]+bl_st), np.zeros(cdata.shape[1]), color = 'k', linewidth = 3) #xaxis
        ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
        ax.set_ylabel('% change HG')
        ax.set_xlabel('time (ms)')
        ax.autoscale(tight=True)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()

        if start_idx.size>0:
            for i, s in enumerate(start_idx):
                tmp = np.arange(s, end_idx[i])
                ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (s, end_idx[i]))
                ax.legend()

        ax.set_title(' '.join([subj, task, ':', str(clustername), str(np.round(chunksize)), 'chunk', str(np.round(black_chunksize)), 'smoothing', str(thresh), 'threshold. Datapoints']))
        plt.savefig(os.path.join(SJdir, 'PCA', 'ShadePlots_hclust','images', ''.join([subj, '_', task, '_', clustername, '.png',])))
        plt.close()

# %% [markdown]
# ## plotting script for output from ShadePlots_clusters_resp.py

# %%
for x in reconlist.values:
    subj_task, _, _,_, _ = x
    subj, task = subj_task.split('_')
    
    files = glob.glob(os.path.join(SJdir, 'PCA', 'ShadePlots_hclust', 'resplocked_all', 'data', ''.join([subj, '_', task, '*.p'])))
    
    for f in files:
        clustername = f.split('_')[-1].split('.')[0]
        
        with open(f, 'r') as x:
            data_dict = pickle.load(x)
            x.close()
    
        #map dictionary to variables
        cdata_resp, bl_st, srate, start_idx, end_idx, chunksize, black_chunksize, cluster, thresh, st_resp, en_resp = [data_dict.get(k) for k in ['cdata_resp','bl_st', 'srate', 'start_idx', 'end_idx', 'chunksize', 'black_chunksize', 'cluster', 'thresh', 'st_resp', 'en_resp']]
        
        #plot
        f, ax = plt.subplots(figsize = (10,10))
        scale_min = cdata_resp.mean(axis = 0).min() - 10
        scale_max = cdata_resp.mean(axis = 0).max() + 10
        tmp = (np.arange(scale_min, scale_max))

        ax.plot(np.arange(st_resp, en_resp), cdata_resp.mean(axis = 0), zorder = 1, linewidth = 3)
        sem = np.std(cdata_resp, axis = 0)/np.sqrt(cdata_resp.shape[0])
        ax.fill_between(np.arange(st_resp, en_resp), cdata_resp.mean(axis = 0)+sem, cdata_resp.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
        ax.plot(np.arange(st_resp, en_resp), np.zeros(cdata_resp.shape[1]), color = 'k', linewidth = 3) #xaxis
        ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
        ax.set_ylabel('% change HG')
        ax.set_xlabel('time (ms)')
        ax.autoscale(tight=True)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()

        if start_idx.size>0:
            for i, s in enumerate(start_idx):
                tmp = np.arange(s, end_idx[i])
                ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (s, end_idx[i]))
                ax.legend()

        ax.set_title(' '.join([subj, task, ':', str(clustername), str(np.round(chunksize)), 'chunk', str(black_chunksize), 'smoothing', str(thresh), 'threshold. Datapoints']))
        plt.savefig(os.path.join(SJdir, 'PCA', 'ShadePlots_hclust','resplocked_all_thresh10','images', ''.join([subj, '_', task, '_', clustername, '.png',])))
        plt.close()

# %% [markdown]
# ##save individual pickle files as csvs - for matlab

# %%
import os
import glob
import pandas as pd
import cPickle as pickle

# %%
SJdir = '/Users/matar/Documents/MATLAB/DATA/Avgusta/'

# %%
reconlist = os.path.join(SJdir, 'PCA', 'reconlist.csv')
reconlist = pd.read_csv(reconlist)

# %%
for x in reconlist.values:
    subj_task, _, _,_, _ = x
    subj, task = subj_task.split('_')
    
    files = glob.glob(os.path.join(SJdir, 'PCA', 'ShadePlots_hclust', 'significance_windows', ''.join([subj, '_', task, '*.p'])))
    
    for f in files:
        clustername = f.split('_')[-1].split('.')[0]
        trials_list = dict()
        
        #load data
        with open(f, 'r') as x:
            data_dict = pickle.load(x)
            x.close()
        
        #pull variables
        pattern = [data_dict.get(k) for k in ['pattern']]
        variable_list = list(data_dict.keys())
        remove_list = ['start_idx_resp','en_resp','RTs','srate','end_idx_resp','pattern','start_idx','st_resp','end_idx','bl_st','cdata_resp', 'cdata','cdata_dur_stim','cdata_dur_resp']
        for j in remove_list:
            if j in variable_list:
                variable_list.remove(j)
            
        #create dataframe
        trials_dict = dict(zip(variable_list, [data_dict.get(k) for k in variable_list]))
        trials_dict['subj'] = [subj] * trials_dict[k].shape[0]
        trials_dict['task'] = [task] * trials_dict[k].shape[0]
        trials_dict['pattern'] = pattern * trials_dict[k].shape[0]
        
        df = pd.DataFrame(trials_dict)
        
        colnames = ['subj','task','pattern']
        tmp = list(df.columns)
        for j in colnames:
            tmp.remove(j)
        colnames.extend(tmp)
        
        df = df[colnames]
        
        #save
        filename = os.path.join(SJdir, 'PCA', 'ShadePlots_hclust', 'significance_windows', 'csv_files', ''.join([subj, '_', task, '_', clustername,'_', pattern[0], '.csv']))
        df.to_csv(filename)

# %%
trials_dict
# Out:
# {'cdata_dur_resp': array([[          nan,           nan,           nan, ...,  -18.35464117,
#           -20.12558069,  -21.90200054],
#         [          nan,           nan,           nan, ...,    6.86713005,
#             8.73739197,   10.67478581],
#         [          nan,           nan,           nan, ...,  -35.5011375 ,
#           -36.28078698,  -37.04055684],
#         ...,
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#   'JH10',
#           21706.17777101,   73468.35596843,   -8432.09622576,
#           -5386.32281228,  149005.16384881,   21670.29107688,
#            8401.74075606,  -11537.28494081,   32800.7561163 ,
#           30498.87153799,   23664.23525476,   -5409.34018586,
#           91264.71749354,   12390.95682426,   67627.29536129,
#          -22120.79730228,   38905.37752443,   15685.89302366,
#          276964.23419305,  115852.61834299,   68038.93651162,
#           61251.55361617,   31890.34598457,  160269.6112571 ,
#          102334.9905614 ,   20093.78806698,   -1441.46086643,
#          162402.70916548,   30105.26296779,  108510.14395137,
#           -1129.45927259,  111154.59907658,  170908.15274888,
#          -29198.14271769,   44695.67977804,   42744.71741249,
#           23031.86412103,  -26244.63272665,   28240.43950556,
#           89969.92045969,  -42251.17959559,   56432.0231151 ,
#          100969.88807307,   33153.29502295,   84178.44835418,
#          118777.80346637,  -26209.72139565,  135674.88207962,
#           43346.29409367,  136515.7818042 ,   41090.14030421,
#           29563.10503677,  130177.49664787,  132967.46304887,
#          153651.05354942,    -310.69593779,   55878.25108773,
#           57662.67035579,   81605.62485998,  -11795.38123379,
#          187693.72285072,   93368.30598461,  -17670.02600846,
#           35007.90920857,   91778.98800608,  144575.46600681,
#           74773.4919669 ,  134377.05614278,   15739.75232279,
#           65467.18796081,  200532.92322331,   21975.48769692,
#          184474.45728698,   97706.48120549,  231412.4568639 ,
#           75518.58124806,   14908.52218927,   36264.97337467,
#          108904.00159716,   14849.3751007 ,  101635.10556568,
#           58221.40138043,   38876.63352517,   70777.06746425,
#           80381.41514999,   39773.57488068,  119300.92007581,
#           60618.16343959,  109853.57191195,   67053.23124535,
#            4236.93211167,  126712.82268622,   41649.01187473,
#          217623.60896206,   82431.67843023,   78904.79543218,
#          209230.00429564,   15882.8820446 ,  145946.75644346,
#           80736.22105183]),
#  'task': ['SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud',
#   'SelfAud']}

# %%
x
# Out:
# ['subj',
#  'task',
#  'pattern',
#  'lats',
#  'lats_pro',
#  'maxes',
#  'means',
#  'stds',
#  'sums']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-166-bcfe7e317ffd> in <module>()
# ----> 1 ['subj','task','pattern'].append(tmp.remove([['subj','task','pattern']]))
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ## this is the code that went into ShadePlots_clusters.py

# %%
subj = 'GP15'
task = 'EmoGen'

filenames = glob.glob(os.path.join(SJdir, 'PCA', 'SingleTrials_hclust', '_'.join([subj, task, 'c*mat'])))

# %%
filename = filenames[0]
data = loadmat.loadmat(filename)

# %%
filename.split('_')[-1].split('.')[0][1:]
# Out:
# '1'

# %%
cdata = data['cdata']
srate = data['srate']

# %%
chunk_size = 100
baseline = -500
thresh = 15
black_chunksize = 0

# %%
#convert to srate
bl_st = baseline/1000*srate
chunksize = chunk_size/1000*srate
blackchunksize = black_chunksize/1000*srate

if task in ['DecisionAud']:
    st_tp = 600/1000*srate
elif task in ['DecisionVis']:
    st_tp = 500/1000*srate
else:
    st_tp = 0

pvals = list();
nozero = np.copy(cdata)
nozero[:,nozero.mean(axis=0)<0] = 0 #zero out negative values

for t in np.arange(abs(bl_st)+st_tp, cdata.shape[1]):
    (t, p) = stats.ttest_1samp(nozero[:,t], 0)
    pvals.append(p)

thr = fdr_correct.fdr2(pvals, q = 0.05)
H = np.array((pvals<thr)).astype('int')

start_idx = np.zeros((1,))
end_idx = np.zeros((1,))

if (thr>0):
    #find elecs with window that > chunksize and > threshold (10%)
    passed_thresh = cdata[:, abs(bl_st)+st_tp::].mean(axis=0)>thresh
    sig_and_thresh = H * passed_thresh
    difference = np.diff(sig_and_thresh, n = 1, axis = 0)
    start_idx = np.where(difference==1)[0]+1
    end_idx = np.where(difference == -1)[0]

    if start_idx.size > end_idx.size: #last chunk goes until end
        end_idx = np.append(end_idx, int(cdata.shape[1]-abs(bl_st)-st_tp))

    elif start_idx.size < end_idx.size:
        start_idx = np.append(0, start_idx) #starts immediately significant

    if (start_idx.size!=0):
        if (start_idx[0] > end_idx[0]): #starts immediately significant
            start_idx = np.append(0, start_idx)
    if (start_idx.size!=0):
        if (end_idx[-1] < start_idx[-1]):#significant until end
            end_idx = np.append(end_idx, int(cdata.shape[1]-abs(bl_st)-st_tp))

    start_idx = start_idx + st_tp #shift by st_tp
    end_idx = end_idx + st_tp
    chunk = (end_idx - start_idx) >= chunksize
    
    if sum(chunk) > 0:
        #significant windows on those that passed threshold (10%) (ignoring threshold and chunksize)
        difference = np.diff(H, n = 1, axis = 0)
        start_idx = np.where(difference==1)[0]+1
        end_idx = np.where(difference == -1)[0]

        if start_idx.size > end_idx.size: #last chunk goes until end
            end_idx = np.append(end_idx, int(cdata.shape[1]-abs(bl_st)-st_tp))

        elif start_idx.size < end_idx.size:
            start_idx = np.append(0, start_idx) #starts immediately significant

        if (start_idx.size!=0):
            if (start_idx[0] > end_idx[0]): #starts immediately significant
                start_idx = np.append(0, start_idx)
        if (start_idx.size!=0):
            if (end_idx[-1] < start_idx[-1]):#significant until end
                end_idx = np.append(end_idx, int(edata.shape[1]-abs(bl_st)-st_tp))

        start_idx = start_idx + st_tp #shift by st_tp
        end_idx = end_idx + st_tp

        black_chunk = (start_idx[1:] - end_idx[:-1])> black_chunksize #combine window separated by <200ms

        tmp = np.append(1,black_chunk).astype('bool')
        end_idx = end_idx[np.append(np.where(np.in1d(start_idx, start_idx[tmp]))[0][1:]-1, -1)]
        start_idx = start_idx[tmp]           

        #drop chunks that <100ms
        chunk = (end_idx - start_idx) >= chunksize
        start_idx = start_idx[chunk]
        end_idx = end_idx[chunk]
        
    else: #no chunks
        start_idx = np.zeros((1,))
        end_idx = np.zeros((1,))

else: #thr<0
    start_idx = np.zeros((1,))
    end_idx = np.zeros((1,))

#subjs.extend([subj] * len(start_idx))
#tasks.extend([task] * len(end_idx))
#elecs.extend([e] * len(start_idx))
#pthr.extend([thr] * len(end_idx))
#starts.extend(start_idx)
#ends.extend(end_idx)

# %%
#plot
f, ax = plt.subplots(figsize = (10,10))
scale_min = cdata.mean(axis = 0).min() - 10
scale_max = cdata.mean(axis = 0).max() + 10
tmp = (np.arange(scale_min, scale_max))

ax.plot(np.arange(bl_st, cdata.shape[1]+bl_st), cdata.mean(axis = 0), zorder = 1, linewidth = 3)
sem = np.std(cdata, axis = 0)/np.sqrt(cdata.shape[0])
ax.fill_between(np.arange(bl_st, cdata.shape[1]+bl_st), cdata.mean(axis = 0)+sem, cdata.mean(axis=0)-sem, alpha = 0.5, zorder = 0, edgecolor = 'None', facecolor = 'slateblue')
ax.plot(np.arange(bl_st, cdata.shape[1]+bl_st), np.zeros(cdata.shape[1]), color = 'k', linewidth = 3) #xaxis
ax.plot(np.zeros(tmp.size), tmp, color = 'k', linewidth = 3) #yaxis
ax.set_ylabel('% change HG')
ax.set_xlabel('time (ms)')
ax.autoscale(tight=True)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

if start_idx.size>0:
    for i, s in enumerate(start_idx):
        tmp = np.arange(s, end_idx[i])
        ax.plot(tmp, np.zeros(tmp.size), color = 'r', linewidth = 3.5, label = (start, finish))
        ax.legend()

#ax.set_title(' '.join([subj, task, ':', 'electrode', str(e)]))
#plt.savefig(os.path.join(SJdir, 'PCA', 'ShadePlots_allelecs', ''.join([subj, '_', task, '_e', str(e), '_bigwindow'])))
#plt.close()
